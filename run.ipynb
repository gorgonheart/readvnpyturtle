# %%
# %matplotlib inline

from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt

from turtleEngine import BacktestingEngine

# %%
engine = BacktestingEngine()
engine.setPeriod(datetime(2014, 1, 1), datetime(2018, 12, 30))
engine.initPortfolio('setting.csv', 10000000)

engine.loadData()
engine.runBacktesting()
engine.showResult()
# Out:
# 投资组合的合约代码['IF99', 'I99', 'RB99', 'TA99']
# 投资组合的初始价值10000000
# IF99数据加载完成，总数据量：1220
# I99数据加载完成，总数据量：1220
# RB99数据加载完成，总数据量：1220
# TA99数据加载完成，总数据量：1220
# 全部数据加载完成
# 开始回放K线数据
# K线数据回放结束
# 开始统计回测结果
# ------------------------------
# 首个交易日：	2014-01-02 00:00:00
# 最后交易日：	2018-12-28 00:00:00
# 总交易日：	1220
# 盈利交易日	543
# 亏损交易日：	560
# 起始资金：	10000000
# 结束资金：	64,867,853.61
# 总收益率：	548.68%
# 年化收益：	39.63%
# 总盈亏：	54,867,853.61
# 最大回撤: 	-12,533,647.12
# 百分比最大回撤: -21.77%
# 总手续费：	567,668.99
# 总滑点：	134,606.9
# 总成交笔数：	565.0
# 日均盈亏：	44,973.65
# 日均手续费：	465.3
# 日均滑点：	110.33
# 日均成交笔数：	0.0
# 日均收益率：	0.17%
# 收益标准差：	1.54%
# Sharpe Ratio：	1.66

# %%
tradeList = engine.getTradeData('IF99')
for trade in tradeList:
    print '%s %s %s %s@%s' %(trade.vtSymbol, trade.direction, trade.offset,
                             trade.volume, trade.price)
# Out:
# IF99 多 开仓 8@2175.2
# IF99 多 开仓 8@2195.8
# IF99 多 开仓 8@2216.2
# IF99 多 开仓 8@2236.8
# IF99 空 平仓 32@2165.2
# IF99 空 开仓 9@2130.0
# IF99 空 开仓 9@2111.8
# IF99 空 开仓 9@2093.4
# IF99 多 平仓 27@2166.8
# IF99 多 开仓 11@2176.2
# IF99 多 开仓 11@2191.6
# IF99 空 平仓 22@2129.6
# IF99 多 开仓 14@2182.4
# IF99 多 开仓 14@2194.0
# IF99 多 开仓 14@2205.6
# IF99 多 开仓 14@2217.4
# IF99 空 平仓 56@2339.4
# IF99 多 开仓 11@2399.6
# IF99 多 开仓 11@2414.6
# IF99 多 开仓 11@2429.6
# IF99 多 开仓 11@2444.8
# IF99 空 平仓 44@2394.4
# IF99 多 开仓 9@2484.6
# IF99 空 平仓 9@2428.8
# IF99 空 开仓 10@2379.4
# IF99 多 平仓 10@2446.8
# IF99 多 开仓 10@2499.6
# IF99 多 开仓 10@2516.6
# IF99 多 开仓 10@2533.6
# IF99 多 开仓 10@2550.4
# IF99 空 平仓 40@3509.0
# IF99 多 开仓 3@3659.2
# IF99 多 开仓 3@3707.0
# IF99 多 开仓 3@3761.4
# IF99 多 开仓 3@3806.2
# IF99 空 平仓 12@4531.2
# IF99 多 开仓 2@5370.6
# IF99 空 平仓 2@4994.8
# IF99 空 开仓 2@4711.2
# IF99 空 开仓 2@4617.0
# IF99 空 开仓 2@4522.8
# IF99 多 平仓 6@4899.8
# IF99 空 开仓 2@4464.6
# IF99 空 开仓 2@4358.6
# IF99 空 开仓 2@4252.6
# IF99 空 开仓 2@4146.6
# IF99 多 平仓 8@3991.2
# IF99 空 开仓 1@3272.8
# IF99 空 开仓 1@3160.8
# IF99 空 开仓 1@3034.0
# IF99 空 开仓 1@2936.4
# IF99 多 平仓 4@3341.0
# IF99 多 开仓 4@3786.6
# IF99 多 开仓 4@3831.8
# IF99 空 平仓 8@3650.4
# IF99 空 开仓 4@3504.4
# IF99 空 开仓 4@3460.4
# IF99 空 开仓 4@3416.4
# IF99 空 开仓 4@3372.6
# IF99 多 平仓 16@2969.2
# IF99 多 开仓 4@3245.2
# IF99 空 平仓 4@3093.8
# IF99 空 开仓 6@2905.2
# IF99 空 开仓 6@2878.0
# IF99 空 开仓 6@2850.8
# IF99 多 平仓 18@3137.8
# IF99 多 开仓 5@3165.6
# IF99 空 平仓 5@3033.8
# IF99 多 开仓 6@3166.6
# IF99 多 开仓 6@3194.4
# IF99 多 开仓 6@3222.4
# IF99 多 开仓 6@3250.4
# IF99 空 平仓 24@3173.6
# IF99 多 开仓 7@3245.6
# IF99 多 开仓 7@3268.6
# IF99 多 开仓 7@3291.4
# IF99 多 开仓 7@3314.4
# IF99 空 平仓 28@3227.8
# IF99 空 开仓 8@3189.8
# IF99 多 平仓 8@3260.4
# IF99 多 开仓 9@3294.2
# IF99 空 平仓 9@3433.0
# IF99 空 开仓 9@3220.6
# IF99 空 开仓 9@3202.0
# IF99 多 平仓 18@3277.0
# IF99 多 开仓 8@3352.0
# IF99 多 开仓 8@3372.2
# IF99 多 开仓 8@3392.2
# IF99 空 平仓 24@3383.4
# IF99 多 开仓 10@3456.6
# IF99 多 开仓 10@3473.2
# IF99 空 平仓 20@3407.0
# IF99 多 开仓 10@3474.4
# IF99 多 开仓 10@3491.0
# IF99 多 开仓 10@3509.2
# IF99 空 平仓 30@3442.2
# IF99 空 开仓 10@3371.6
# IF99 空 开仓 10@3355.4
# IF99 空 开仓 10@3339.0
# IF99 多 平仓 30@3404.4
# IF99 多 开仓 10@3433.6
# IF99 多 开仓 10@3449.8
# IF99 多 开仓 10@3466.0
# IF99 多 开仓 10@3482.2
# IF99 空 平仓 40@3657.0
# IF99 多 开仓 6@4103.6
# IF99 空 平仓 6@3996.6
# IF99 多 开仓 6@4105.4
# IF99 多 开仓 6@4132.2
# IF99 多 开仓 6@4159.0
# IF99 多 开仓 6@4186.0
# IF99 空 平仓 24@4253.2
# IF99 空 开仓 5@3937.4
# IF99 空 开仓 5@3902.4
# IF99 空 开仓 5@3867.4
# IF99 空 开仓 5@3832.4
# IF99 多 平仓 20@4010.2
# IF99 空 开仓 5@3704.4
# IF99 多 平仓 5@3832.8
# IF99 多 开仓 6@3922.2
# IF99 空 平仓 6@3822.0
# IF99 空 开仓 6@3714.2
# IF99 多 平仓 6@3827.6
# IF99 空 开仓 6@3667.4
# IF99 空 开仓 6@3659.2
# IF99 空 开仓 6@3631.0
# IF99 空 开仓 6@3602.8
# IF99 多 平仓 24@3476.2
# IF99 空 开仓 4@3272.8
# IF99 空 开仓 4@3234.4
# IF99 多 平仓 8@3387.8
# IF99 空 开仓 4@3224.6
# IF99 空 开仓 4@3189.8
# IF99 多 平仓 8@3346.8
# IF99 空 开仓 5@3188.4
# IF99 多 平仓 5@3325.4
# IF99 多 开仓 5@3425.0
# IF99 多 开仓 5@3457.6
# IF99 空 平仓 10@3326.8
# IF99 空 开仓 5@3183.6
# IF99 空 开仓 5@3150.8
# IF99 空 开仓 5@3118.0
# IF99 空 开仓 5@3085.2
# IF99 多 平仓 20@3216.6
# IF99 空 开仓 5@3113.2
# IF99 空 开仓 5@3083.0
# IF99 空 开仓 5@3052.6
# IF99 空 开仓 5@3022.2
